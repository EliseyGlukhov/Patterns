# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov5/yolov5m.pt')
# Out:
# PRO TIP  Replace 'model=yolov5/yolov5m.pt' with new 'model=yolov5/yolov5mu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100%|██████████| 48.2M/48.2M [03:18<00:00, 254kB/s]

# %%
model.train(data='dataset/data.yaml', epochs=1)
# Out:
# Ultralytics YOLOv8.1.43  Python-3.11.2 torch-2.2.2+cpu CPU (12th Gen Intel Core(TM) i7-12700KF)
# ...

# %%
result = model.predict('dataset/test/images', conf=0.8, save=True)
# Out:
# image 1/10 d:\task05.04.24\dataset\test\images\screenshot_1664704636694.png: 384x640 3 cars, 144.0ms
# image 2/10 d:\task05.04.24\dataset\test\images\screenshot_1664704639331.png: 384x640 3 cars, 2 plates, 182.0ms
# image 3/10 d:\task05.04.24\dataset\test\images\screenshot_1664704642016.png: 384x640 3 cars, 1 plate, 149.0ms
# image 4/10 d:\task05.04.24\dataset\test\images\screenshot_1664704644928.png: 384x640 4 cars, 1 plate, 178.0ms
# image 5/10 d:\task05.04.24\dataset\test\images\screenshot_1664704646787.png: 384x640 3 cars, 1 plate, 163.0ms
# image 6/10 d:\task05.04.24\dataset\test\images\screenshot_1664704648798.png: 384x640 3 cars, 1 plate, 147.0ms
# image 7/10 d:\task05.04.24\dataset\test\images\screenshot_1664704650328.png: 384x640 4 cars, 2 plates, 169.0ms
# image 8/10 d:\task05.04.24\dataset\test\images\screenshot_1664704651629.png: 384x640 4 cars, 1 plate, 172.0ms
# image 9/10 d:\task05.04.24\dataset\test\images\screenshot_1664704654305.png: 384x640 2 cars, 146.8ms
# ...

# %%
from PIL import Image
# %matplotlib inline
import matplotlib.pyplot as plt
import os
path = 'runs/detect/train9/'
images = os.listdir(path)

for image in images:
    im = Image.open(path + image)
    plt.imshow(im)
    plt.show()
